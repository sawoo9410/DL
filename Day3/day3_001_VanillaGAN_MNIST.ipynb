# %% [markdown]
# ### Created on 2023
# ### @author: S.W
#
# #### References
# - https://www.tensorflow.org/tutorials/generative/dcgan?hl=ko
# - https://colab.research.google.com/drive/1v7OYMjLF1zkYUzcuCSUdpzUmIm_dCPPz#scrollTo=pZuOPwpc8dNa

# %% [markdown]
# -----

# %% [markdown]
# ### 1. 학습에 필요한 라이브러리 불러오기

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt
import numpy as np
import os
import time

# %% [markdown]
# ### 2. MNIST 데이터 불러오기 & 이미지 데이터 전처리
#
# #### 이미지 데이터 전처리

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images - 127.5) / 127.5
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32')
test_images = (test_images - 127.5) / 127.5
# 마지막 layer의 활성화 함수로 sigmoid(0~1) 보다 tanh(-1~1)를 더 선호합니다.

print(train_images.shape)
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# #### 훈련 데이터셋에서 이미지 추출 후 랜덤 시각화

# %%
# 훈련 데이터셋에서 16개의 이미지 랜덤 선택
images = train_images[np.random.choice(train_images.shape[0], size=16, replace=False)]

# 이미지 시각화
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i, :, :, 0], cmap='gray')
    ax.axis('off')
plt.show()

# %% [markdown]
# #### 데이터를 batch_size 단위로 분할

# %%
BUFFER_SIZE = 60000 # buffer_size는 몇 개의 데이터를 버퍼에 담을지를 결정합니다.
BATCH_SIZE = 128
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ### 3. Vanilla GAN 모델 정의
# #### 생성자 모델
# - G 모델은 Noise로 부터 원래의 데이터를 생성해내는 모델입니다.
# - Input : 100차원의 noise
# - Output : Mnist 이미지 크기인 28*28

# %%
inputs = keras.Input(shape=(100,))
x = inputs
x = layers.Dense(256)(x)
x = layers.LeakyReLU()(x)
x = layers.Dense(28*28, activation = 'tanh')(x)
outputs = layers.Reshape((28,28))(x)

G = keras.Model(inputs, outputs)
G.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               25856
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               201488
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 227,344
# Trainable params: 227,344
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 판별자 모델
# - D모델은 28*28 이미지가 실제 데이터인지 만들어진 데이터인지 판별합니다.
# - Input : Mnist 이미지 (28*28)
# - Output : 실제 데이터 일 확률 (0~1 사이의 값)

# %%
inputs = keras.Input(shape=(28,28))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.LeakyReLU()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1)(x)

D = keras.Model(inputs, outputs)
D.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               200960
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 201,217
# Trainable params: 201,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 랜덤 값으로 테스트 해보기

# %%
# 임의의 Noise를 G모델에 통과시키면 28*28 사이즈의 랜덤 이미지가 만들어집니다.
test_noise = tf.random.normal([1, 100])
fake_image_test = G(test_noise, training=False)

plt.imshow(fake_image_test[0], cmap='gray')

# %%
# 그리고 G모델에서 만들어진 이미지를 D모델에 통과시키면 확률이 나오게 됩니다.
decision = D(fake_image_test, training=False)
print(decision)
# Out:
# tf.Tensor([[0.6034105]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ### 4. 모델 학습 파라미터 설정

# %%
EPOCHS = 50
noise_dim = 100

seed = tf.random.normal([BATCH_SIZE, noise_dim])

# 최적화 방법: Adam
G_optimizer = tf.keras.optimizers.Adam(1e-4)
D_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
# 손실함수: 이진 교차 엔트로피
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def D_loss(real_output, fake_output):
    """
    판별자의 목표는 실제 데이터를 실제로, 가짜 데이터를 가짜로 올바르게 분류하는 것
    실제 데이터와 가짜 데이터를 정확하게 구별할 수록 작아지는 값을 가지게 됩니다.
    """
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def G_loss(fake_output):
    """
    fake_output이라는 텐서를 인자로 받을 때, tf.ones_like(fake_output)는 fake_output과 동일한 형태(shape)와
    데이터 타입(dtype)을 가진 텐서를 생성하고, 이 텐서의 모든 원소를 1로 초기화합니다.

    이 함수는 주로 GAN의 생성자 손실을 계산할 때 사용됩니다.
    생성자의 목표는 가짜 데이터를 생성하여 판별자가 실제 데이터로 분류하도록 속이는 것이므로,
    생성자 손실을 계산할 때 가짜 출력에 대한 실제 레이블(1로 채워진 벡터)이 필요합니다.
    
    이 때 tf.ones_like(fake_output)를 사용하여 가짜 출력과 동일한 형태의 1로 채워진 텐서를 생성할 수 있습니다.
    """
    # 생성자 손실함수
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# ### 5. 모델 학습
#
# #### 훈련 데이터셋 학습 함수 정의

# %%
# 아래의 train_step 함수에는 @tf.function이라는 데코레이터가 사용됩니다.
# 특정한 상황일때 함수를 'compile' 하여 속도가 빨라진다고 대략적으로 이해하시면 됩니다!
@tf.function
def train_step(real_images):  
  
    noises = tf.random.normal([BATCH_SIZE, noise_dim])
  
    with tf.GradientTape() as gen_tape, tf.GradientTape() as dsc_tape:
        # tf.GradientTape()를 사용하여 생성자(G)와 판별자(D) 모델을 학습시키는데 필요한 연산들을 기록
        # gen_tape과 dsc_tape는 각각 생성자와 판별자 모델의 손실 함수에 대한 기울기(gradient)를 계산하기 위해 사용
        fake_images = G(noises, training=True)

        real_output = D(real_images, training=True)
        fake_output = D(fake_images, training=True)

        gen_loss = G_loss(fake_output)
        dsc_loss = D_loss(real_output, fake_output)
    
    # 손실 함수값을 이용하여 gen_tape.gradient 함수와 dsc_tape.gradient 함수를 사용하여 각 모델의 기울기(gradient)를 계산
    gen_gradients = gen_tape.gradient(gen_loss, G.trainable_variables)
    dsc_gradients = dsc_tape.gradient(dsc_loss, D.trainable_variables)
  
    # G_optimizer.apply_gradients와 D_optimizer.apply_gradients 함수를 사용하여 기울기를 이용하여 각 모델의 가중치를 업데이트
    G_optimizer.apply_gradients(zip(gen_gradients, G.trainable_variables)) 
    D_optimizer.apply_gradients(zip(dsc_gradients, D.trainable_variables))

# %% [markdown]
# #### 테스트 데이터셋 학습 함수 정의

# %%
def test_step(real_images):  
    noises = tf.random.normal([BATCH_SIZE, noise_dim])
  
    fake_images = G(noises, training=False)
  
    real_output = D(real_images, training=False)
    fake_output = D(fake_images, training=False)    
  
    gen_loss = G_loss(fake_output)
    dsc_loss = D_loss(real_output, fake_output)
  
    print("Generator loss:", gen_loss.numpy(), "Discriminator loss:", dsc_loss.numpy())
    
    return gen_loss.numpy(), dsc_loss.numpy()

# %% [markdown]
# #### 손실함수 그래프 함수 정의

# %%
def plot_loss(losses) :
    plt.figure(figsize=(10,10))

    plt.plot(losses[0], label="Generator losses")
    plt.plot(losses[1], label="Discriminator losses")
    plt.xlabel("Epochs")
    plt.ylabel("Losses")
    plt.legend()
    plt.show()

# %% [markdown]
# #### 전체 학습함수 정의

# %%
def train(dataset, epochs):
    gen_losses = []
    dsc_losses = []

    for epoch in range(epochs):
        start = time.time()
    
        for i, image_batch in enumerate(dataset):
            train_step(image_batch)
            if i == 0:
                gen_loss, dsc_loss = test_step(image_batch)
                gen_losses.append(gen_loss)
                dsc_losses.append(dsc_loss)
        print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-
# Time for epoch 27 is 2.2559642791748047 sec
# Generator loss: 1.5144233 Discriminator loss: 0.7171099
# Time for epoch 28 is 2.2326157093048096 sec
# Generator loss: 1.5301775 Discriminator loss: 0.71591514
# Time for epoch 29 is 2.24568247795105 sec
# Generator loss: 1.4192159 Discriminator loss: 0.68450606
# Time for epoch 30 is 2.2774624824523926 sec
# Generator loss: 1.421731 Discriminator loss: 0.6936114
# Time for epoch 31 is 2.2338624000549316 sec
# Generator loss: 1.3135858 Discriminator loss: 0.74964154
# Time for epoch 32 is 2.224153518676758 sec
# Generator loss: 1.4523852 Discriminator loss: 0.6590694
# Time for epoch 33 is 2.253462553024292 sec
# Generator loss: 1.29371 Discriminator loss: 0.61223215
# Time for epoch 34 is 2.251664876937866 sec
# Generator loss: 1.2910211 Discriminator loss: 0.7415179
# Time for epoch 35 is 2.244492292404175 sec
# Generator loss: 2.2268014 Discriminator loss: 0.49929595
# Time for epoch 36 is 2.3037900924682617 sec
# Generator loss: 1.645713 Discriminator loss: 0.6571045
# Time for epoch 37 is 2.1785595417022705 sec
# Generator loss: 1.609735 Discriminator loss: 0.6721612
# Time for epoch 38 is 2.2848000526428223 sec
# Generator loss: 1.2633255 Discriminator loss: 0.74100757
# Time for epoch 39 is 2.2460310459136963 sec
# Generator loss: 1.3249786 Discriminator loss: 0.6938149
# Time for epoch 40 is 2.2477564811706543 sec
# Generator loss: 1.4644139 Discriminator loss: 0.74055946
# Time for epoch 41 is 2.2564520835876465 sec
# Generator loss: 1.3986518 Discriminator loss: 0.8055104
# Time for epoch 42 is 2.225731611251831 sec
# Generator loss: 1.096336 Discriminator loss: 0.8220308
# Time for epoch 43 is 2.2480077743530273 sec
# Generator loss: 1.0452949 Discriminator loss: 0.8533302
# Time for epoch 44 is 2.2275846004486084 sec
# Generator loss: 1.1652579 Discriminator loss: 0.83352435
# Time for epoch 45 is 2.2161500453948975 sec
# Generator loss: 1.2484221 Discriminator loss: 0.88352144
# Time for epoch 46 is 2.253887414932251 sec
# Generator loss: 1.3139967 Discriminator loss: 0.7845816
# Time for epoch 47 is 2.2250683307647705 sec
# Generator loss: 1.2855767 Discriminator loss: 0.85343003
# Time for epoch 48 is 2.2510905265808105 sec
# Generator loss: 1.542137 Discriminator loss: 0.78890574
# Time for epoch 49 is 2.250471591949463 sec
# Generator loss: 1.0506232 Discriminator loss: 0.810591
# Time for epoch 50 is 2.2564597129821777 sec

# %% [markdown]
# ### 6. 임의의 노이즈 벡터를 입력 후 결과 확인

# %%
# Generator가 만들어 낸 노이즈 이미지 테스트 해보기

import matplotlib.pyplot as plt

noises = tf.random.normal([50, 100])
generated_image = G(noises, training=False)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10,10))

for ax in axes.flat:
    ax.axis('off')

axes[0,0].imshow(generated_image[0], cmap='gray')
axes[0,1].imshow(generated_image[1], cmap='gray')
axes[1,0].imshow(generated_image[2], cmap='gray')
axes[1,1].imshow(generated_image[3], cmap='gray')
axes[2,0].imshow(generated_image[4], cmap='gray')
axes[2,1].imshow(generated_image[5], cmap='gray')

plt.show()
