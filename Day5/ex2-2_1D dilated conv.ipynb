# %%
# -*- coding: utf-8 -*-
"""
Demonstration of 1-D Time Dilitated Convolutions

https://colab.research.google.com/github/tensorchiefs/dl_book/blob/master/chapter_02/nb_ch02_04.ipynb

WaveNet: A Generative Model for Raw Audio

Wavenet:  https://velog.io/@changdaeoh/Convolutionforsequence

Wavenet:  https://velog.io/@changdaeoh/Convolutionforsequence

"""

# %%
# Import required libraries:
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten , Activation, Lambda, Conv1D
from tensorflow.keras.utils import to_categorical 

##---- An other simple toy example ----##

# Creation of the training data
np.random.seed(1) # Fixing the seed, so that data is always the same
seq_length = 128  # Sequence length used for training
look_ahead =  10  # The number of data points the model should predict 

def gen_data(size=1000, noise=0.1): # We create 1000 data-points
  s = seq_length + look_ahead
  d = np.zeros((size, s,1))
  for i in range(size):
    start = np.random.uniform(0, 2*np.pi) # Random start point
    d[i,:,0] = np.sin(start + np.linspace(0, 20*np.pi, s)) * np.sin(start + np.linspace(0, np.pi, s)) + np.random.normal(0,noise,s)
  return d[:,0:seq_length], d[:,seq_length:s]

X,Y = gen_data()
for i in range(1):
  plt.plot(range(0, seq_length),X[i,:,0],'b-')
  plt.plot(range(seq_length, seq_length + look_ahead),Y[i,:,0],'bo',color='orange')
plt.show()

print('The training data X (solid) line and the next predictions Y (dotted), which should be forecasted.')
#The training data X (solid) line and the next predictions Y (dotted), which should be forecasted.

X.shape, Y.shape
#((1000, 128, 1), (1000, 10, 1))

def slice(x, slice_length):
    return x[:,-slice_length:,:]
  
model = Sequential()
ks = 5
model.add(Conv1D(filters=32, kernel_size=ks, padding='causal', batch_input_shape=(None, None, 1)))
model.add(Conv1D(filters=32, kernel_size=ks, padding='causal'))
model.add(Conv1D(filters=32, kernel_size=ks, padding='causal'))
model.add(Conv1D(filters=32, kernel_size=ks, padding='causal'))
model.add(Dense(1))
model.add(Lambda(slice, arguments={'slice_length':look_ahead}))

model.summary()
model.compile(optimizer='adam', loss='mean_squared_error')

history1 = model.fit(X[0:800], Y[0:800],
                    epochs=100,
                    batch_size=128,
                    validation_data=(X[800:1000],Y[800:1000]),
                    verbose=1)

plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# Testing on new data
X,Y = gen_data(noise=0)
res = model.predict(X) 
print('Shapes X {} Y{} res{}'.format(X.shape, Y.shape, res.shape))
print('MSE for complete look-ahead ', np.average((res[:,:,0] - Y[:,:,0])**2)) 
print('MSE for one step look-ahead ', np.average((res[:,0,0] - Y[:,0,0])**2)) 
print('MSE baseline (same as last)', np.average((X[:,-1,0] - Y[:,0,0])**2)) 
#Shapes X (1000, 128, 1) Y(1000, 10, 1) res(1000, 10, 1)
#MSE for complete look-ahead  0.006175160843588977
#MSE for one step look-ahead  0.011793306071592236
#MSE baseline (same as last) 0.061507885229804334

x_test,y_test = gen_data(size=1,noise=0.0)
model.predict(x_test).reshape(-1),y_test.reshape(-1)

#(array([ 0.9797643 ,  0.9846904 ,  0.7957371 ,  0.4545659 ,  0.033907  ,
#        -0.37807393, -0.6964255 , -0.8570964 , -0.82994324, -0.62439007],
#       dtype=float32),
#array([ 0.85230934,  0.88453287,  0.73468149,  0.43794298,  0.05913728,
#        -0.32152731, -0.6255856 , -0.7926458 , -0.7924877 , -0.63048301]))
    
# Prediction one after another
def predict_sequence(input_sequence, model, pred_steps):

    history_sequence = input_sequence.copy()
    pred_sequence = np.zeros((1,pred_steps * look_ahead,1)) # initialize output (pred_steps time steps)  
    
    for i in range(pred_steps):
        
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)[0,-look_ahead:,0]
        pred_sequence[0,(i * look_ahead) : ((i+1) * look_ahead),0] = last_step_pred
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence, 
                                           last_step_pred.reshape(-1,look_ahead,1)], axis=1)

    return pred_sequence

plt.figure(num=None, figsize=(13,5))
pred_steps = 10
x_test,y_test = gen_data(size=1,noise=0.0)
preds = predict_sequence(x_test, model, pred_steps)
plt.plot(range(0,len(x_test[0])),x_test[0,:,0])
plt.plot(range(len(x_test[0]),len(x_test[0])+len(preds[0])),preds[0,:,0],color='orange')
plt.ylim((-1,1))

##---- The model with time dilated convolutions ----##

X,Y = gen_data(noise=0)

model_dil = Sequential()
#<------ Just replaced this block
model_dil.add(Conv1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=1, 
                           batch_input_shape=(None, None, 1)))
model_dil.add(Conv1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=2))
model_dil.add(Conv1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=4))
model_dil.add(Conv1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=8))
#<------ Just replaced this block

model_dil.add(Dense(1))
model_dil.add(Lambda(slice, arguments={'slice_length':look_ahead}))

model_dil.summary()

model_dil.compile(optimizer='adam',loss='mean_squared_error')

hist_dil = model_dil.fit(X[0:800], Y[0:800],
                    epochs=200,
                    batch_size=128,
                    validation_data=(X[800:1000],Y[800:1000]), verbose=1)

plt.plot(hist_dil.history['loss'])
plt.plot(hist_dil.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time (Dilated)')
plt.legend(['Train','Valid'])

# Testing
X,Y = gen_data()
res = model_dil.predict(X) 
print('MSE for one step look-ahead ', np.average((res[:,0,0] - Y[:,0,0])**2)) #One step look-ahead prediction
print('MSE baseline (same as last)', np.average((X[:,-1,0] - Y[:,0,0])**2)) 
#MSE for one step look-ahead  0.014241653115197758
#MSE baseline (same as last) 0.08379639134464463

plt.figure(num=None, figsize=(13,5))
pred_steps = 10
x_test,y_test = gen_data(size=1,noise=0.0)
preds = predict_sequence(x_test, model_dil, pred_steps)
plt.plot(range(0,len(x_test[0])),x_test[0,:,0])
plt.plot(range(len(x_test[0]),len(x_test[0])+len(preds[0])),preds[0,:,0],color='orange')
plt.ylim((-1,1))
# Out:
# C:\Users\sangwoo\AppData\Local\Temp\ipykernel_2168\1058155265.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(range(seq_length, seq_length + look_ahead),Y[i,:,0],'bo',color='orange')
# The training data X (solid) line and the next predictions Y (dotted), which should be forecasted.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, None, 32)          192
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           33
# _________________________________________________________________
# lambda (Lambda)              (None, None, 1)           0
# =================================================================
# Total params: 15,681
# Trainable params: 15,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 3s 60ms/step - loss: 0.1149 - val_loss: 0.0559
# Epoch 2/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0487 - val_loss: 0.0518
# Epoch 3/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0432 - val_loss: 0.0393
# Epoch 4/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - val_loss: 0.0318
# Epoch 5/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0355 - val_loss: 0.0301
# Epoch 6/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0291
# Epoch 7/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0275
# Epoch 8/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0298 - val_loss: 0.0257
# Epoch 9/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0283 - val_loss: 0.0251
# Epoch 10/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0272 - val_loss: 0.0238
# Epoch 11/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0260 - val_loss: 0.0231
# Epoch 12/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0253 - val_loss: 0.0231
# Epoch 13/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0250 - val_loss: 0.0228
# Epoch 14/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 0.0229
# Epoch 15/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 0.0225
# Epoch 16/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0247 - val_loss: 0.0225
# Epoch 17/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0245 - val_loss: 0.0225
# Epoch 18/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0245 - val_loss: 0.0229
# Epoch 19/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0245 - val_loss: 0.0228
# Epoch 20/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.0227
# Epoch 21/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0244 - val_loss: 0.0224
# Epoch 22/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 0.0223
# Epoch 23/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0226
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0242 - val_loss: 0.0225
# Epoch 25/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0241 - val_loss: 0.0225
# Epoch 26/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0228
# Epoch 27/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 0.0224
# Epoch 28/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0243 - val_loss: 0.0223
# Epoch 29/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0223
# Epoch 30/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0222
# Epoch 31/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 0.0220
# Epoch 32/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0241 - val_loss: 0.0223
# Epoch 33/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0226
# Epoch 34/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0225
# Epoch 35/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 0.0220
# Epoch 36/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 0.0220
# Epoch 37/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0221
# Epoch 38/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0237 - val_loss: 0.0221
# Epoch 39/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0219
# Epoch 40/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0223
# Epoch 41/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0220
# Epoch 42/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0219
# Epoch 43/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0218
# Epoch 44/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0235 - val_loss: 0.0218
# Epoch 45/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 46/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0218
# Epoch 47/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0221
# Epoch 48/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.0233
# Epoch 49/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.0233
# Epoch 50/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0241 - val_loss: 0.0222
# Epoch 51/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0226
# Epoch 52/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0237 - val_loss: 0.0218
# Epoch 53/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0225
# Epoch 54/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239 - val_loss: 0.0232
# Epoch 55/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0230
# Epoch 56/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0233
# Epoch 57/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0224
# Epoch 58/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0233
# Epoch 59/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0244 - val_loss: 0.0238
# Epoch 60/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0243 - val_loss: 0.0228
# Epoch 61/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0223
# Epoch 62/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0225
# Epoch 63/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0226
# Epoch 64/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0223
# Epoch 65/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0237 - val_loss: 0.0222
# Epoch 66/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 67/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0218
# Epoch 68/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0217
# Epoch 69/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0221
# Epoch 70/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0217
# Epoch 71/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0234 - val_loss: 0.0224
# Epoch 72/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0235 - val_loss: 0.0218
# Epoch 73/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0219
# Epoch 74/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0237 - val_loss: 0.0225
# Epoch 75/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237 - val_loss: 0.0231
# Epoch 76/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0223
# Epoch 77/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0235
# Epoch 78/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0244 - val_loss: 0.0226
# Epoch 79/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0230
# Epoch 80/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0220
# Epoch 81/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237 - val_loss: 0.0222
# Epoch 82/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 83/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0218
# Epoch 84/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237 - val_loss: 0.0218
# Epoch 85/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0218
# Epoch 86/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0220
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0218
# Epoch 88/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0235 - val_loss: 0.0227
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0240 - val_loss: 0.0223
# Epoch 90/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0231
# Epoch 91/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0220
# Epoch 92/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0228
# Epoch 93/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0224
# Epoch 94/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0237 - val_loss: 0.0221
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237 - val_loss: 0.0219
# Epoch 96/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0235 - val_loss: 0.0219
# Epoch 97/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0219
# Epoch 98/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0220
# Epoch 99/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239 - val_loss: 0.0222
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0226
# Shapes X (1000, 128, 1) Y(1000, 10, 1) res(1000, 10, 1)
# MSE for complete look-ahead  0.006899907609215929
# MSE for one step look-ahead  0.017557960709896122
# MSE baseline (same as last) 0.06147579415035294
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, None, 32)          192
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 1)           33
# _________________________________________________________________
# lambda_1 (Lambda)            (None, None, 1)           0
# =================================================================
# Total params: 15,681
# Trainable params: 15,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
#
200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0113e-14 - val_loss: 1.0694e-14
# Epoch 158/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0251e-14 - val_loss: 1.0795e-14
# Epoch 159/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0238e-14 - val_loss: 1.0833e-14
# Epoch 160/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0256e-14 - val_loss: 1.0934e-14
# Epoch 161/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0137e-14 - val_loss: 1.0765e-14
# Epoch 162/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0191e-14 - val_loss: 1.0480e-14
# Epoch 163/200
# 7/7 [==============================] - 0s 6ms/step - loss: 9.9668e-15 - val_loss: 1.0584e-14
# Epoch 164/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0245e-14 - val_loss: 1.0478e-14
# Epoch 165/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0073e-14 - val_loss: 1.0798e-14
# Epoch 166/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0269e-14 - val_loss: 1.0937e-14
# Epoch 167/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0093e-14 - val_loss: 1.0820e-14
# Epoch 168/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0191e-14 - val_loss: 1.0914e-14
# Epoch 169/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0012e-14 - val_loss: 1.0771e-14
# Epoch 170/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0024e-14 - val_loss: 1.0713e-14
# Epoch 171/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0107e-14 - val_loss: 1.1086e-14
# Epoch 172/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0087e-14 - val_loss: 1.1064e-14
# Epoch 173/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0239e-14 - val_loss: 1.0991e-14
# Epoch 174/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0320e-14 - val_loss: 1.1153e-14
# Epoch 175/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0226e-14 - val_loss: 1.0894e-14
# Epoch 176/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0295e-14 - val_loss: 1.0939e-14
# Epoch 177/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0213e-14 - val_loss: 1.0676e-14
# Epoch 178/200
# 7/7 [==============================] - 0s 6ms/step - loss: 9.9343e-15 - val_loss: 1.1103e-14
# Epoch 179/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0119e-14 - val_loss: 1.0922e-14
# Epoch 180/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0345e-14 - val_loss: 1.0917e-14
# Epoch 181/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0029e-14 - val_loss: 1.0875e-14
# Epoch 182/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0207e-14 - val_loss: 1.0962e-14
# Epoch 183/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0134e-14 - val_loss: 1.2190e-14
# Epoch 184/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2026e-14 - val_loss: 1.5296e-14
# Epoch 185/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4978e-14 - val_loss: 1.2017e-14
# Epoch 186/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0326e-14 - val_loss: 1.1674e-14
# Epoch 187/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0285e-14 - val_loss: 1.1349e-14
# Epoch 188/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0473e-14 - val_loss: 1.1198e-14
# Epoch 189/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0259e-14 - val_loss: 1.1373e-14
# Epoch 190/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0220e-14 - val_loss: 1.1017e-14
# Epoch 191/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0921e-14 - val_loss: 1.3550e-14
# Epoch 192/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2771e-14 - val_loss: 1.2442e-14
# Epoch 193/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1300e-14 - val_loss: 1.1482e-14
# Epoch 194/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0716e-14 - val_loss: 1.2448e-14
# Epoch 195/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1018e-14 - val_loss: 1.1200e-14
# Epoch 196/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0202e-14 - val_loss: 1.0943e-14
# Epoch 197/200
# 7/7 [==============================] - 0s 6ms/step - loss: 9.8920e-15 - val_loss: 1.0694e-14
# Epoch 198/200
# 7/7 [==============================] - 0s 6ms/step - loss: 9.9960e-15 - val_loss: 1.0461e-14
# Epoch 199/200
# 7/7 [==============================] - 0s 6ms/step - loss: 9.8996e-15 - val_loss: 1.0750e-14
# Epoch 200/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0007e-14 - val_loss: 1.0474e-14
# MSE for one step look-ahead  0.0138062207583153
# MSE baseline (same as last) 0.08270541455379668
# (-1.0, 1.0)
